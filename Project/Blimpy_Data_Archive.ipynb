# %%
import blimpy
import matplotlib.pyplot as plt

# %%
file1 = "blc21_guppi_57991_66219_DIAG_FRB121102_0020.gpuspec.0002.fil"
w1 = blimpy.Waterfall(file1)

# %%
w1.info()
# Out:
# --- File Info ---
#   b'rawdatafile' : b'guppi_57991_66219_DIAG_FRB121102_0020.0000.raw'
#   b'source_name' :                b'DIAG_FRB121102'
#    b'machine_id' :                               20
#  b'telescope_id' :                                6
#       b'src_raj' :                     5h31m58.536s
#       b'src_dej' :                     33d08m51.36s
#      b'az_start' :                              0.0
#      b'za_start' :                              0.0
#     b'data_type' :                                1
#          b'fch1' :                    6501.46484375
#          b'foff' :             -0.00286102294921875
#        b'nchans' :                            65536
#        b'nbeams' :                                1
#         b'ibeam' :                                1
#         b'nbits' :                               32
#        b'tstart' :                57991.76642361111
#         b'tsamp' :               1.0737418239999998
# ...

# %%
data1 = w1.data
freqsw1 = w1.populate_freqs()
data1.shape
# Out:
# (1169, 1, 65536)

# %%
plt.figure()
plt.scatter(freqsw1, data1[12])

# %%
print(data1)
# Out:
# [[[3.7580500e+09 3.7418033e+09 3.7709752e+09 ... 4.0655923e+09
#    4.1157793e+09 4.1728922e+09]]
#
#  [[3.6540846e+09 3.6768056e+09 3.7507853e+09 ... 4.1117568e+09
#    4.1132662e+09 4.1085414e+09]]
#
#  [[3.6598054e+09 3.7263949e+09 3.8667950e+09 ... 4.1614508e+09
#    4.0376143e+09 3.9913344e+09]]
#
#  ...
#
#  [[3.1111076e+09 3.1829804e+09 3.1300698e+09 ... 3.4064730e+09
#    3.4537992e+09 3.4406976e+09]]
#
#  [[3.0868326e+09 3.1836063e+09 3.1351854e+09 ... 3.4148531e+09
#    3.4560840e+09 3.4465034e+09]]
#
#  [[3.2349466e+09 3.1643374e+09 3.1751373e+09 ... 3.4271181e+09
#    3.3965453e+09 3.4184438e+09]]]

# %%
help(blimpy.Waterfall)
# Out:
# Help on class Waterfall in module blimpy.waterfall:
#
# class Waterfall(blimpy.filterbank.Filterbank)
#  |  Waterfall(filename=None, f_start=None, f_stop=None, t_start=None, t_stop=None, load_data=True, max_load=1.0, header_dict=None, data_array=None)
#  |
#  |  Class for loading and writing blimpy data (.fil, .h5)
#  |
#  |  Method resolution order:
#  |      Waterfall
#  |      blimpy.filterbank.Filterbank
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, filename=None, f_start=None, f_stop=None, t_start=None, t_stop=None, load_data=True, max_load=1.0, header_dict=None, data_array=None)
#  |      Class for loading and plotting blimpy data.
#  |
#  |      This class parses the blimpy file and stores the header and data
#  |      as objects:
#  |          fb = Waterfall('filename_here.fil')
#  |          fb.header        # blimpy header, as a dictionary
#  |          fb.data          # blimpy data, as a numpy array
#  |
#  |      Args:
# ...

# %%
help(blimpy)
# Out:
# Help on package blimpy:
#
# NAME
#     blimpy
#
# PACKAGE CONTENTS
#     dice
#     fil2h5
#     file_wrapper
#     filterbank
#     gup2hdf
#     guppi
#     h52fil
#     match_fils
#     sigproc
#     utils
#     waterfall
#
# DATA
#     absolute_import = _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0...
#
# VERSION
#     1.3.5
#
# FILE
#     c:\users\ocean\anaconda3\lib\site-packages\blimpy\__init__.py

# %% [markdown]
# w1.plot_waterfall()

# %%
w1.plot_waterfall()

# %%
w1.plot_spectrum()
# Out:
# extracting integration 0...

# %%
w1.plot_time_series()

# %%
w1.plot_kurtosis()
# Out:
# C:\Users\ocean\Anaconda3\lib\site-packages\scipy\stats\stats.py:951: RuntimeWarning: overflow encountered in square
#   s = s**2
# C:\Users\ocean\Anaconda3\lib\site-packages\numpy\core\_methods.py:75: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims)

# %%
help(blimpy.Waterfall.plot_kurtosis)
# Out:
# Help on function plot_kurtosis in module blimpy.filterbank:
#
# plot_kurtosis(self, f_start=None, f_stop=None, if_id=0, **kwargs)
#     Plot kurtosis
#
#     Args:
#        f_start (float): start frequency, in MHz
#        f_stop (float): stop frequency, in MHz
#        kwargs: keyword args to be passed to matplotlib imshow()

# %%
help(blimpy.Waterfall)
# Out:
# Help on class Waterfall in module blimpy.waterfall:
#
# class Waterfall(blimpy.filterbank.Filterbank)
#  |  Waterfall(filename=None, f_start=None, f_stop=None, t_start=None, t_stop=None, load_data=True, max_load=1.0, header_dict=None, data_array=None)
#  |
#  |  Class for loading and writing blimpy data (.fil, .h5)
#  |
#  |  Method resolution order:
#  |      Waterfall
#  |      blimpy.filterbank.Filterbank
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, filename=None, f_start=None, f_stop=None, t_start=None, t_stop=None, load_data=True, max_load=1.0, header_dict=None, data_array=None)
#  |      Class for loading and plotting blimpy data.
#  |
#  |      This class parses the blimpy file and stores the header and data
#  |      as objects:
#  |          fb = Waterfall('filename_here.fil')
#  |          fb.header        # blimpy header, as a dictionary
#  |          fb.data          # blimpy data, as a numpy array
#  |
#  |      Args:
# ...
